# %% [markdown]
# # Working with the gamer word

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [a for a in range(100)]

plt.plot(x, x)

plt.show()

# %%
import yfinance as yf

hist = yf.Ticker('msft').history(period="max")
hist['Close'].plot()

plt.show()

# %% [markdown]
# This is a pretty neat little tool for writing up notes. Lovin' it
